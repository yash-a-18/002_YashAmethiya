# %%
#Importing libraries
import numpy as np 
import pandas as pd

# %%
# reading the csv file, del 2 columns from the file, checking first few rows of the file

data = pd.read_csv('BuyComputer.csv')

data.drop(columns=['User ID',],axis=1,inplace=True)
data.head()
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0

# %%
#Declare label as last column in the source file
label = data.iloc[:,-1].values

# %%
#Declaring X as all columns excluding last
X = data.iloc[:,:-1].values

# %%
# Splitting data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, label, test_size = 0.20, random_state = 2)

# %%
# Sacaling data
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
#Variabes to calculate sigmoid function
y_pred = []
len_x = len(X_train[0])
w = []
b = 0.2
print(len_x)
# Out:
# 2

# %%
entries = len(X_train[:,0])
entries
# Out:
# 320

# %%
for weights in range(len_x):
    w.append(0)
w
# Out:
# [0, 0]

# %%
# Sigmoid function
def sigmoid(z):
  return (1 / (1 + np.exp(-z)))

# %%
def predict(inputs):
    z = np.dot(w,inputs) + b
    temp = sigmoid(z)
    return temp

# %%
#Loss function
def loss_func(y,a):
    J = -(y * np.log(a) + (1-y) * np.log(1-a))
    return J

# %%
dw = []
db = 0
J = 0
alpha = 0.1
for x in range(len_x):
    dw.append(0)

# %%
#Repeating the process 3000 times
for iterations in range(3000):
    for i in range(entries):
        localx = X_train[i]
        a = predict(localx)   
        dz = a - y_train[i]
        J += loss_func(y_train[i],a)

        for j in range(len_x):
            dw[j] = dw[j] + (localx[j] * dz)

        db += dz
    J = J / entries
    db = db / entries

    for x in range(len_x):
        dw[x] = dw[x] / entries

    for x in range(len_x):
        w[x] = w[x] - (alpha * dw[x])
    b = b - (alpha * db)         
    J=0

# %%
#Print weight
w
# Out:
# [2.4496026554675985, 1.2925941519089577]

# %%
#print bias
b
# Out:
# -1.2686701850651536

# %%
#predicting the label
for x in range(len(y_test)):
    y_pred.append(predict(X_test[x]))

# %%
#print actual and predicted values in a table
print("Actual\t\tPredicted")
for x in range(len(y_pred)):
    print(y_test[x] ,y_pred[x], sep="\t\t")
    if y_pred[x]>=0.5:
        y_pred[x]=1
    else:
        y_pred[x]=0
# Out:
# Actual		Predicted
# 0		0.055897258614097126
# 0		0.0006943455756416955
# 0		0.1112184695182781
# 0		0.041822152780223575
# 1		0.9301748867859769
# 1		0.27460155872130926
# 0		0.013605256319321751
# 0		0.006647533992835981
# 0		0.2493291308388692
# 1		0.6147403606621576
# 0		0.0018408512060153405
# 0		0.001336766293369733
# 1		0.3054320735967659
# 0		0.6908770324757985
# 0		0.08926743154019724
# 0		0.03212989435455523
# 0		0.0033790418816664106
# 1		0.949838404835104
# 1		0.9190224909651161
# 0		0.006302149355380711
# 1		0.24497747422865226
# 1		0.3795286131032668
# 0		0.03259091405465971
# 0		0.04406451683148318
# 0		0.020096684920257752
# 1		0.27150666043226157
# 1		0.20292678598908287
# 0		0.22854833385830123
# 1		0.945546600468696
# 1		0.18702643012712358
# 0		0.0062052539497587265
# 0		0.2367430417724819
# 1		0.2509543834795369
# 0		0.16614097473769146
# 1		0.6073290372300332
# 1		0.24916655590982234
# 1		0.7896891758701744
# 0		0.024254333129473768
# 0		0.012727795819360356
# 1		0.9124762991487564
# 0		0.04373729399655661
# 0		0.39204709176548375
# 0		0.04273392869847881
# 0		0.5331883161277846
# 0		0.002473950885510105
# 1		0.5523176644193561
# 0		0.018507162761120275
# 1		0.39225418908209353
# 1		0.9542636010260841
# 0		0.002176954732088432
# 1		0.0570976042429824
# 1		0.940621247288435
# 0		0.11268218322836768
# 0		0.351022641035891
# 0		0.0995511827815184
# 0		0.005250487447907502
# 0		0.11825493178300822
# 1		0.7685346144946994
# 0		0.9160070023664598
# 0		0.06316274598817882
# 0		0.029369372444229314
# 1		0.9976671846183426
# 1		0.9888818846035836
# 0		0.39019052841141677
# 0		0.029147948240676673
# 1		0.737138933937541
# 1		0.22870155361813996
# 0		0.09307064886864089
# 0		0.050909210810425466
# 1		0.8350545331444393
# 0		0.14990370968748698
# 1		0.9911343407365679
# 0		0.0430897923238712
# 0		0.012727795819360356
# 1		0.9957783213073309
# 0		0.1385757196413978
# 1		0.9946627808003284
# 0		0.006951641754029114
# 1		0.9927677216470291
# 0		0.00673964669677711

# %%
# Calculating accuracy of prediction
count = 0
for x in range(len(y_pred)):
    if(y_pred[x] == y_test[x]):
        count += 1

print('Accuracy:',(count / (len(y_pred))) * 100)
# Out:
# Accuracy: 81.25

# %% [markdown]
# #Using sklearn LogisticRegression model

# %%
# Fitting Logistic Regression to the Training set
from sklearn.linear_model import LogisticRegression
LR = LogisticRegression(random_state = 2) # roll no = 2

#Fit
LR.fit(X_train,y_train)

#predicting the test label with LR. Predict always takes X as input
y_predict = LR.predict(X_test)

from sklearn.metrics import accuracy_score
print('Accuracy:', accuracy_score(y_predict,y_test))
# Out:
# Accuracy: 0.8125

# %% [markdown]
# **Exercise:**
#
# Try logistic regression on BuyComputer dataset and set Random state=Your_RollNumber (last 3 digit of ID, incase if you don't have ID)
